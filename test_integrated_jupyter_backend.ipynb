# %% [markdown]
# # Test Integrated Jupyter Backend
#
# This notebook tests the integrated Jupyter backend functionality where `obj.viz.show(backend='jupyter')` automatically handles server lifecycle management without requiring manual wrapper functions.

# %%
import groggy as gr

# Test the complete viz accessor implementation
g = gr.karate_club()
gt = g.table()
nt = g.nodes.table()
et = g.edges.table()
sg = g.view()
sga = g.connected_components()

# %% [markdown]
# ## Test 1: GraphTable viz with integrated Jupyter backend

# %%
# Get graph table and test integrated Jupyter viz
print(f"GraphTable: {gt}")
print(f"Has viz accessor: {hasattr(gt, 'viz')}")

# Test the integrated Jupyter backend - should automatically manage server lifecycle
viz_html = gt.viz.show(backend='jupyter')
print(f"\nViz HTML generated: {len(viz_html)} characters")
print(f"Contains iframe: {'iframe' in viz_html.lower()}")
print(f"HTML preview: {viz_html[:100]}...")
# Out:
# GraphTable: GraphTable[34 nodes, 78 edges]
# Validation Policy: Standard
# Nodes:
# NodesTable[34 x 3]
# ┌───────┬───────────┬─────────┐
# │ index │ name      │ node_id │
# ├───────┼───────────┼─────────┤
# │     2 │ Member_2  │       2 │
# │    25 │ Member_25 │      25 │
# │    31 │ Member_31 │      31 │
# │    16 │ Member_16 │      16 │
# │     ⋮ │ ⋮         │       ⋮ │
# │     5 │ Member_5  │       5 │
# │    21 │ Member_21 │      21 │
# │    13 │ Member_13 │      13 │
# │    14 │ Member_14 │      14 │
# └───────┴───────────┴─────────┘
# 34 rows x 3 colsEdges:
# EdgesTable[78 x 4]
# ┌─────────┬──────────────┬────────┬────────┐
# │ edge_id │ relationship │ source │ target │
# ├─────────┼──────────────┼────────┼────────┤
# │       6 │ friendship   │      0 │      7 │
# │      34 │ friendship   │      3 │     13 │
# │      55 │ friendship   │     22 │     32 │
# │       0 │ friendship   │      0 │      1 │
# │       ⋮ │ ⋮            │      ⋮ │      ⋮ │
# │       5 │ friendship   │      0 │      6 │
# │      29 │ friendship   │      2 │     27 │
# │      58 │ friendship   │     23 │     27 │
# │       9 │ friendship   │      0 │     11 │
# └─────────┴──────────────┴────────┴────────┘
# 78 rows x 4 cols
# Has viz accessor: True
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 7: Found 0 attributes
# ❌ No 'name' attribute found for node 7, available attrs: ["color", "size"]
# 🔍 Node 19: Found 0 attributes
# ❌ No 'name' attribute found for node 19, available attrs: ["color", "size"]
# 🔍 Node 2: Found 0 attributes
# ❌ No 'name' attribute found for node 2, available attrs: ["size", "color"]
# 📌 Registered Jupyter server on port 59609 for GraphTable (6 total)
#
# Viz HTML generated: 109 characters
# Contains iframe: True
# HTML preview: <iframe src="http://127.0.0.1:59609" width="100%" height="420" style="border:0;border-radius:12px;">...
# 🔍 Node 1: Found 2 attributes
# 🔍   index = SmallInt(1)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 1, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 20: Found 2 attributes
# 🔍   index = SmallInt(20)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 20, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 4: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(4)
# ❌ No 'name' attribute found for node 4, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 15: Found 0 attributes
# ❌ No 'name' attribute found for node 15, available attrs: ["color", "size"]
# 🔍 Node 13: Found 2 attributes
# 🔍   index = SmallInt(13)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 13, available attrs: ["index", "name", "size", "color"]
# 🔍 Node 5: Found 2 attributes
# 🔍   index = SmallInt(5)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 5, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 28: Found 0 attributes
# ❌ No 'name' attribute found for node 28, available attrs: ["color", "size"]
# 🔍 Node 24: Found 0 attributes
# ❌ No 'name' attribute found for node 24, available attrs: ["size", "color"]
# 🔍 Node 14: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(14)
# ❌ No 'name' attribute found for node 14, available attrs: ["size", "index", "name", "color"]
# 🔍 Node 31: Found 0 attributes
# ❌ No 'name' attribute found for node 31, available attrs: ["size", "color"]
# 🔍 Node 32: Found 0 attributes
# ❌ No 'name' attribute found for node 32, available attrs: ["color", "size"]
# 🔍 Node 18: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(18)
# ❌ No 'name' attribute found for node 18, available attrs: ["size", "index", "name", "color"]
# 🔍 Node 9: Found 2 attributes
# 🔍   index = SmallInt(9)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 9, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 30: Found 0 attributes
# ❌ No 'name' attribute found for node 30, available attrs: ["color", "size"]
# 🔍 Node 23: Found 0 attributes
# ❌ No 'name' attribute found for node 23, available attrs: ["size", "color"]
# 🔍 Node 22: Found 0 attributes
# ❌ No 'name' attribute found for node 22, available attrs: ["color", "size"]
# 🔍 Node 8: Found 2 attributes
# 🔍   index = SmallInt(8)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 8, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 17: Found 0 attributes
# ❌ No 'name' attribute found for node 17, available attrs: ["color", "size"]
# 🔍 Node 33: Found 0 attributes
# ❌ No 'name' attribute found for node 33, available attrs: ["size", "color"]
# 🔍 Node 21: Found 2 attributes
# 🔍   index = SmallInt(21)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 21, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 10: Found 2 attributes
# 🔍   index = SmallInt(10)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 10, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 29: Found 0 attributes
# ❌ No 'name' attribute found for node 29, available attrs: ["size", "color"]
# 🔍 Node 11: Found 2 attributes
# 🔍   index = SmallInt(11)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 11, available attrs: ["name", "index", "size", "color"]
# 🔍 Node 26: Found 0 attributes
# ❌ No 'name' attribute found for node 26, available attrs: ["size", "color"]
# 🔍 Node 0: Found 2 attributes
# 🔍   index = SmallInt(0)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 0, available attrs: ["size", "color", "index", "name"]
# 🔍 Node 27: Found 0 attributes
# ❌ No 'name' attribute found for node 27, available attrs: ["size", "color"]
# 🔍 Node 16: Found 0 attributes
# ❌ No 'name' attribute found for node 16, available attrs: ["color", "size"]
# 🔍 Node 12: Found 2 attributes
# 🔍   index = SmallInt(12)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 12, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 6: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 54, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(6)
# ❌ No 'name' attribute found for node 6, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 3: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(3)
# ❌ No 'name' attribute found for node 3, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 25: Found 0 attributes
# ❌ No 'name' attribute found for node 25, available attrs: ["color", "size"]
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 19: Found 0 attributes
# ❌ No 'name' attribute found for node 19, available attrs: ["color", "size"]
# 🔍 Node 20: Found 2 attributes
# 🔍   index = SmallInt(20)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 20, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 6: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 54, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(6)
# ❌ No 'name' attribute found for node 6, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 17: Found 0 attributes
# ❌ No 'name' attribute found for node 17, available attrs: ["color", "size"]
# 🔍 Node 3: Found 2 attributes
# 🔍   index = SmallInt(3)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 3, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 18: Found 2 attributes
# 🔍   index = SmallInt(18)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 18, available attrs: ["size", "name", "color", "index"]
# 🔍 Node 21: Found 2 attributes
# 🔍   index = SmallInt(21)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 21, available attrs: ["color", "name", "index", "size"]
# 🔍 Node 24: Found 0 attributes
# ❌ No 'name' attribute found for node 24, available attrs: ["size", "color"]
# 🔍 Node 0: Found 2 attributes
# 🔍   index = SmallInt(0)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 0, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 10: Found 2 attributes
# 🔍   index = SmallInt(10)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 10, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 27: Found 0 attributes
# ❌ No 'name' attribute found for node 27, available attrs: ["color", "size"]
# 🔍 Node 31: Found 0 attributes
# ❌ No 'name' attribute found for node 31, available attrs: ["color", "size"]
# 🔍 Node 23: Found 0 attributes
# ❌ No 'name' attribute found for node 23, available attrs: ["color", "size"]
# 🔍 Node 11: Found 2 attributes
# 🔍   index = SmallInt(11)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 11, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 12: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(12)
# ❌ No 'name' attribute found for node 12, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 22: Found 0 attributes
# ❌ No 'name' attribute found for node 22, available attrs: ["size", "color"]
# 🔍 Node 4: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(4)
# ❌ No 'name' attribute found for node 4, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 9: Found 2 attributes
# 🔍   index = SmallInt(9)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 9, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 1: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(1)
# ❌ No 'name' attribute found for node 1, available attrs: ["name", "size", "color", "index"]
# 🔍 Node 2: Found 0 attributes
# ❌ No 'name' attribute found for node 2, available attrs: ["color", "size"]
# 🔍 Node 14: Found 2 attributes
# 🔍   index = SmallInt(14)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 14, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 16: Found 0 attributes
# ❌ No 'name' attribute found for node 16, available attrs: ["color", "size"]
# 🔍 Node 32: Found 0 attributes
# ❌ No 'name' attribute found for node 32, available attrs: ["color", "size"]
# 🔍 Node 7: Found 0 attributes
# ❌ No 'name' attribute found for node 7, available attrs: ["size", "color"]
# 🔍 Node 30: Found 0 attributes
# ❌ No 'name' attribute found for node 30, available attrs: ["color", "size"]
# 🔍 Node 25: Found 0 attributes
# ❌ No 'name' attribute found for node 25, available attrs: ["size", "color"]
# 🔍 Node 8: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(8)
# ❌ No 'name' attribute found for node 8, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 15: Found 0 attributes
# ❌ No 'name' attribute found for node 15, available attrs: ["color", "size"]
# 🔍 Node 5: Found 2 attributes
# 🔍   index = SmallInt(5)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 5, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 26: Found 0 attributes
# ❌ No 'name' attribute found for node 26, available attrs: ["size", "color"]
# 🔍 Node 29: Found 0 attributes
# ❌ No 'name' attribute found for node 29, available attrs: ["color", "size"]
# 🔍 Node 33: Found 0 attributes
# ❌ No 'name' attribute found for node 33, available attrs: ["size", "color"]
# 🔍 Node 28: Found 0 attributes
# ❌ No 'name' attribute found for node 28, available attrs: ["size", "color"]
# 🔍 Node 13: Found 2 attributes
# 🔍   index = SmallInt(13)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 13, available attrs: ["index", "name", "size", "color"]
# 🎯 GraphDataSource::interactive_embed called
# ✅ Bound and listening on 127.0.0.1:59609
# 📊 Serving 34 rows × 4 columns
# 🖼️  Graph visualization iframe generated for port 59609

# %% [markdown]
# ## Test 2: Subgraph viz with integrated Jupyter backend

# %%
# Create subgraph and test integrated Jupyter viz
print(f"Subgraph: {sg}")
print(f"Has viz accessor: {hasattr(sg, 'viz')}")

# Test the integrated Jupyter backend
viz_html = sg.viz.show(backend='jupyter')
print(f"\nViz HTML generated: {len(viz_html)} characters")
print(f"Contains iframe: {'iframe' in viz_html.lower()}")
print(f"HTML preview: {viz_html[:100]}...")
# Out:
# Subgraph: Subgraph with 34 nodes and 78 edges
#
# Edges:
#   ID    Source → Target
#   ----  ---------------
#     42       8 → 32
#     53      20 → 32
#     51      18 → 33
#     63      24 → 27
#      7       0 → 8
#     27       2 → 9
#      8       0 → 10
#     41       8 → 30
#     22       1 → 21
#      3       0 → 4
#     44       9 → 33
#     73      30 → 32
#     59      23 → 29
#     36       4 → 10
#     72      29 → 33
#      2       0 → 3
#     39       5 → 16
#     10       0 → 12
#     18       1 → 7
#      6       0 → 7
#     20       1 → 17
#     43       8 → 33
#     33       3 → 12
#     11       0 → 13
#     40       6 → 16
#     54      20 → 33
#     66      26 → 29
#     60      23 → 32
#     19       1 → 13
#     46      14 → 32
#      4       0 → 5
#      1       0 → 2
#     14       0 → 21
#     77      32 → 33
#     26       2 → 8
#     37       5 → 6
#     67      26 → 33
#     30       2 → 28
#     58      23 → 27
#     48      15 → 32
#      5       0 → 6
#     16       1 → 2
#     61      23 → 33
#     15       0 → 31
#     29       2 → 27
#     75      31 → 32
#     70      28 → 33
#     35       4 → 6
#     57      23 → 25
#     55      22 → 32
#     28       2 → 13
#     62      24 → 25
#     74      30 → 33
#     69      28 → 31
#     49      15 → 33
#     38       5 → 10
#     21       1 → 19
#     47      14 → 33
#     12       0 → 17
#     23       1 → 30
#     64      24 → 31
#     34       3 → 13
#     17       1 → 3
#     65      25 → 31
#      9       0 → 11
#     45      13 → 33
#     56      22 → 33
#     50      18 → 32
#      0       0 → 1
#     76      31 → 33
#     32       3 → 7
#     24       2 → 3
#     71      29 → 32
#     25       2 → 7
#     13       0 → 19
#     52      19 → 33
#     68      27 → 33
#     31       2 → 32
# Has viz accessor: True
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 15: Found 0 attributes
# ❌ No 'name' attribute found for node 15, available attrs: ["color", "size"]
# 🔍 Node 10: Found 2 attributes
# 🔍   index = SmallInt(10)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 10, available attrs: ["color", "name", "index", "size"]
# 🔍 Node 21: Found 0 attributes
# ❌ No 'name' attribute found for node 21, available attrs: ["color", "size"]
# 🔍 Node 14: Found 2 attributes
# 🔍   index = SmallInt(14)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 14, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 19: Found 0 attributes
# ❌ No 'name' attribute found for node 19, available attrs: ["size", "color"]
# 🔍 Node 3: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(3)
# ❌ No 'name' attribute found for node 3, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 1: Found 2 attributes
# 🔍   index = SmallInt(1)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 1, available attrs: ["color", "index", "name", "size"]
# 🔍 Node 32: Found 0 attributes
# ❌ No 'name' attribute found for node 32, available attrs: ["size", "color"]
# 🔍 Node 22: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(22)
# ❌ No 'name' attribute found for node 22, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 11: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(11)
# ❌ No 'name' attribute found for node 11, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 12: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(12)
# ❌ No 'name' attribute found for node 12, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 31: Found 0 attributes
# ❌ No 'name' attribute found for node 31, available attrs: ["color", "size"]
# 🔍 Node 23: Found 0 attributes
# ❌ No 'name' attribute found for node 23, available attrs: ["color", "size"]
# 🔍 Node 25: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(25)
# ❌ No 'name' attribute found for node 25, available attrs: ["color", "name", "index", "size"]
# 🔍 Node 27: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(27)
# ❌ No 'name' attribute found for node 27, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 5: Found 2 attributes
# 🔍   index = SmallInt(5)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 5, available attrs: ["color", "name", "size", "index"]
# 🔍 Node 18: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(18)
# ❌ No 'name' attribute found for node 18, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 30: Found 0 attributes
# ❌ No 'name' attribute found for node 30, available attrs: ["size", "color"]
# 🔍 Node 20: Found 2 attributes
# 🔍   index = SmallInt(20)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 20, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 33: Found 0 attributes
# ❌ No 'name' attribute found for node 33, available attrs: ["color", "size"]
# 🔍 Node 16: Found 0 attributes
# ❌ No 'name' attribute found for node 16, available attrs: ["color", "size"]
# 🔍 Node 8: Found 2 attributes
# 🔍   index = SmallInt(8)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 8, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 4: Found 2 attributes
# 🔍   index = SmallInt(4)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 4, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 0: Found 2 attributes
# 🔍   index = SmallInt(0)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 0, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 2: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(2)
# ❌ No 'name' attribute found for node 2, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 6: Found 0 attributes
# ❌ No 'name' attribute found for node 6, available attrs: ["size", "color"]
# 🔍 Node 24: Found 0 attributes
# ❌ No 'name' attribute found for node 24, available attrs: ["color", "size"]
# 🔍 Node 9: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(9)
# ❌ No 'name' attribute found for node 9, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 13: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(13)
# ❌ No 'name' attribute found for node 13, available attrs: ["size", "color", "index", "name"]
# 🔍 Node 7: Found 2 attributes
# 🔍   index = SmallInt(7)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 55, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 7, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 28: Found 0 attributes
# ❌ No 'name' attribute found for node 28, available attrs: ["color", "size"]
# 🔍 Node 26: Found 0 attributes
# ❌ No 'name' attribute found for node 26, available attrs: ["color", "size"]
# 🔍 Node 17: Found 2 attributes
# 🔍   index = SmallInt(17)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 17, available attrs: ["color", "size", "name", "index"]
# 🔍 Node 29: Found 0 attributes
# ❌ No 'name' attribute found for node 29, available attrs: ["color", "size"]
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 3: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(3)
# ❌ No 'name' attribute found for node 3, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 14: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(14)
# ❌ No 'name' attribute found for node 14, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 2: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(2)
# ❌ No 'name' attribute found for node 2, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 17: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(17)
# ❌ No 'name' attribute found for node 17, available attrs: ["color", "name", "index", "size"]
# 🔍 Node 16: Found 0 attributes
# ❌ No 'name' attribute found for node 16, available attrs: ["color", "size"]
# 🔍 Node 18: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(18)
# ❌ No 'name' attribute found for node 18, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 28: Found 0 attributes
# ❌ No 'name' attribute found for node 28, available attrs: ["size", "color"]
# 🔍 Node 9: Found 2 attributes
# 🔍   index = SmallInt(9)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 9, available attrs: ["index", "size", "color", "name"]
# 🔍 Node 25: Found 2 attributes
# 🔍   index = SmallInt(25)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 25, available attrs: ["name", "index", "size", "color"]
# 🔍 Node 24: Found 0 attributes
# ❌ No 'name' attribute found for node 24, available attrs: ["size", "color"]
# 🔍 Node 30: Found 0 attributes
# ❌ No 'name' attribute found for node 30, available attrs: ["color", "size"]
# 🔍 Node 0: Found 2 attributes
# 🔍   index = SmallInt(0)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 0, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 7: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 55, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(7)
# ❌ No 'name' attribute found for node 7, available attrs: ["index", "size", "color", "name"]
# 🔍 Node 6: Found 0 attributes
# ❌ No 'name' attribute found for node 6, available attrs: ["color", "size"]
# 🔍 Node 19: Found 0 attributes
# ❌ No 'name' attribute found for node 19, available attrs: ["size", "color"]
# 🔍 Node 21: Found 0 attributes
# ❌ No 'name' attribute found for node 21, available attrs: ["color", "size"]
# 🔍 Node 22: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(22)
# ❌ No 'name' attribute found for node 22, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 23: Found 0 attributes
# ❌ No 'name' attribute found for node 23, available attrs: ["color", "size"]
# 🔍 Node 1: Found 2 attributes
# 🔍   index = SmallInt(1)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 1, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 5: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(5)
# ❌ No 'name' attribute found for node 5, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 20: Found 2 attributes
# 🔍   index = SmallInt(20)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50📌 Registered Jupyter server on port 58886 for Subgraph (7 total)
#
# Viz HTML generated: 109 characters
# Contains iframe: True
# HTML preview: <iframe src="http://127.0.0.1:58886" width="100%" height="420" style="border:0;border-radius:12px;">...
# , 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 20, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 29: Found 0 attributes
# ❌ No 'name' attribute found for node 29, available attrs: ["size", "color"]
# 🔍 Node 13: Found 2 attributes
# 🔍   index = SmallInt(13)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 13, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 10: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(10)
# ❌ No 'name' attribute found for node 10, available attrs: ["color", "size", "name", "index"]
# 🔍 Node 12: Found 2 attributes
# 🔍   index = SmallInt(12)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 12, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 15: Found 0 attributes
# ❌ No 'name' attribute found for node 15, available attrs: ["size", "color"]
# 🔍 Node 27: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(27)
# ❌ No 'name' attribute found for node 27, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 31: Found 0 attributes
# ❌ No 'name' attribute found for node 31, available attrs: ["size", "color"]
# 🔍 Node 33: Found 0 attributes
# ❌ No 'name' attribute found for node 33, available attrs: ["size", "color"]
# 🔍 Node 8: Found 2 attributes
# 🔍   index = SmallInt(8)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 8, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 32: Found 0 attributes
# ❌ No 'name' attribute found for node 32, available attrs: ["color", "size"]
# 🔍 Node 4: Found 2 attributes
# 🔍   index = SmallInt(4)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 4, available attrs: ["name", "index", "size", "color"]
# 🔍 Node 26: Found 0 attributes
# ❌ No 'name' attribute found for node 26, available attrs: ["size", "color"]
# 🔍 Node 11: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(11)
# ❌ No 'name' attribute found for node 11, available attrs: ["name", "color", "size", "index"]
# 🎯 GraphDataSource::interactive_embed called
# ✅ Bound and listening on 127.0.0.1:58886
# 📊 Serving 34 rows × 4 columns
# 🖼️  Graph visualization iframe generated for port 58886

# %% [markdown]
# ## Test 3: SubgraphArray viz with integrated Jupyter backend

# %%
# Create subgraph array and test integrated Jupyter viz
print(f"SubgraphArray: {sga}")
print(f"Has viz accessor: {hasattr(sga, 'viz')}")

# Test the integrated Jupyter backend
viz_html = sga.viz.show(backend='jupyter')
print(f"\nViz HTML generated: {len(viz_html)} characters")
print(f"Contains iframe: {'iframe' in viz_html.lower()}")
print(f"HTML preview: {viz_html[:100]}...")
# Out:
# SubgraphArray: ComponentsArray(1 components)
# Has viz accessor: True
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 27: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(13)
# ❌ No 'name' attribute found for node 27, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 3: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(32)
# ❌ No 'name' attribute found for node 3, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 13: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(1)
# ❌ No 'name' attribute found for node 13, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 1: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(28)
# ❌ No 'name' attribute found for node 1, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 2: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(2)
# ❌ No 'name' attribute found for node 2, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 8: Found 2 attributes
# 🔍   index = SmallInt(9)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 8, available attrs: ["index", "size", "color", "name"]
# 🔍 Node 18: Found 2 attributes
# 🔍   index = SmallInt(24)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 18, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 22: Found 2 attributes
# 🔍   index = SmallInt(29)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 57, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No📌 Registered Jupyter server on port 58897 for ComponentsArray (8 total)
#
# Viz HTML generated: 109 characters
# Contains iframe: True
# HTML preview: <iframe src="http://127.0.0.1:58897" width="100%" height="420" style="border:0;border-radius:12px;">...
#  'name' attribute found for node 22, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 4: Found 2 attributes
# 🔍   index = SmallInt(21)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 4, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 19: Found 2 attributes
# 🔍   index = SmallInt(22)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 19, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 0: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(0)
# ❌ No 'name' attribute found for node 0, available attrs: ["name", "size", "color", "index"]
# 🔍 Node 11: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(11)
# ❌ No 'name' attribute found for node 11, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 29: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 57, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(19)
# ❌ No 'name' attribute found for node 29, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 31: Found 2 attributes
# 🔍   index = SmallInt(33)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 31, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 6: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 54, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(16)
# ❌ No 'name' attribute found for node 6, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 9: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(25)
# ❌ No 'name' attribute found for node 9, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 17: Found 2 attributes
# 🔍   index = SmallInt(6)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 54, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 17, available attrs: ["name", "size", "color", "index"]
# 🔍 Node 32: Found 2 attributes
# 🔍   index = SmallInt(20)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 32, available attrs: ["name", "index", "size", "color"]
# 🔍 Node 5: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(8)
# ❌ No 'name' attribute found for node 5, available attrs: ["index", "color", "name", "size"]
# 🔍 Node 7: Found 2 attributes
# 🔍   index = SmallInt(18)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 7, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 12: Found 2 attributes
# 🔍   index = SmallInt(10)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 12, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 16: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(15)
# ❌ No 'name' attribute found for node 16, available attrs: ["color", "size", "name", "index"]
# 🔍 Node 25: Found 2 attributes
# 🔍   index = SmallInt(26)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 54, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 25, available attrs: ["index", "size", "color", "name"]
# 🔍 Node 30: Found 2 attributes
# 🔍   index = SmallInt(4)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 30, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 15: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(27)
# ❌ No 'name' attribute found for node 15, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 21: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(17)
# ❌ No 'name' attribute found for node 21, available attrs: ["size", "name", "color", "index"]
# 🔍 Node 24: Found 2 attributes
# 🔍   index = SmallInt(5)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 24, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 20: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(12)
# ❌ No 'name' attribute found for node 20, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 10: Found 2 attributes
# 🔍   index = SmallInt(23)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 10, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 28: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 55, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(7)
# ❌ No 'name' attribute found for node 28, available attrs: ["color", "name", "index", "size"]
# 🔍 Node 33: Found 2 attributes
# 🔍   index = SmallInt(30)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 33, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 23: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(3)
# ❌ No 'name' attribute found for node 23, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 26: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(31)
# ❌ No 'name' attribute found for node 26, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 14: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(14)
# ❌ No 'name' attribute found for node 14, available attrs: ["size", "color", "name", "index"]
# GROGGY DEBUG: GraphDataSource::new called with 34 nodes
# 🔍 Node 10: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(23)
# ❌ No 'name' attribute found for node 10, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 29: Found 2 attributes
# 🔍   index = SmallInt(19)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 57, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 29, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 22: Found 2 attributes
# 🔍   index = SmallInt(29)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 57, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 22, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 27: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(13)
# ❌ No 'name' attribute found for node 27, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 6: Found 2 attributes
# 🔍   index = SmallInt(16)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 54, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 6, available attrs: ["color", "size", "name", "index"]
# 🔍 Node 1: Found 2 attributes
# 🔍   index = SmallInt(28)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 1, available attrs: ["name", "color", "index", "size"]
# 🔍 Node 5: Found 2 attributes
# 🔍   index = SmallInt(8)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 56, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 5, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 24: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 53, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(5)
# ❌ No 'name' attribute found for node 24, available attrs: ["size", "name", "color", "index"]
# 🔍 Node 9: Found 2 attributes
# 🔍   index = SmallInt(25)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 9, available attrs: ["size", "name", "color", "index"]
# 🔍 Node 16: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 53, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(15)
# ❌ No 'name' attribute found for node 16, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 8: Found 2 attributes
# 🔍   index = SmallInt(9)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 57, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 8, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 18: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(24)
# ❌ No 'name' attribute found for node 18, available attrs: ["size", "index", "name", "color"]
# 🔍 Node 21: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(17)
# ❌ No 'name' attribute found for node 21, available attrs: ["color", "size", "index", "name"]
# 🔍 Node 32: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(20)
# ❌ No 'name' attribute found for node 32, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 3: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(32)
# ❌ No 'name' attribute found for node 3, available attrs: ["name", "size", "color", "index"]
# 🔍 Node 7: Found 2 attributes
# 🔍   index = SmallInt(18)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 56, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 7, available attrs: ["color", "size", "name", "index"]
# 🔍 Node 4: Found 2 attributes
# 🔍   index = SmallInt(21)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 4, available attrs: ["index", "color", "size", "name"]
# 🔍 Node 2: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(2)
# ❌ No 'name' attribute found for node 2, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 23: Found 2 attributes
# 🔍   index = SmallInt(3)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 23, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 14: Found 2 attributes
# 🔍   index = SmallInt(14)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 52, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 14, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 26: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(31)
# ❌ No 'name' attribute found for node 26, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 30: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 52, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(4)
# ❌ No 'name' attribute found for node 30, available attrs: ["size", "name", "index", "color"]
# 🔍 Node 33: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(30)
# ❌ No 'name' attribute found for node 33, available attrs: ["size", "color", "index", "name"]
# 🔍 Node 28: Found 2 attributes
# 🔍   index = SmallInt(7)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 55, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 28, available attrs: ["name", "color", "size", "index"]
# 🔍 Node 11: Found 2 attributes
# 🔍   index = SmallInt(11)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 49, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 11, available attrs: ["index", "size", "name", "color"]
# 🔍 Node 0: Found 2 attributes
# 🔍   index = SmallInt(0)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 48, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# ❌ No 'name' attribute found for node 0, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 17: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 54, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(6)
# ❌ No 'name' attribute found for node 17, available attrs: ["name", "size", "index", "color"]
# 🔍 Node 25: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 54, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(26)
# ❌ No 'name' attribute found for node 25, available attrs: ["name", "size", "color", "index"]
# 🔍 Node 13: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 0, 0, 0, 0, 0, 0, 0], len: 8 })
# 🔍   index = SmallInt(1)
# ❌ No 'name' attribute found for node 13, available attrs: ["index", "name", "color", "size"]
# 🔍 Node 19: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(22)
# ❌ No 'name' attribute found for node 19, available attrs: ["size", "color", "name", "index"]
# 🔍 Node 15: Found 2 attributes
# 🔍   index = SmallInt(27)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 50, 55, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 15, available attrs: ["size", "index", "color", "name"]
# 🔍 Node 20: Found 2 attributes
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 50, 0, 0, 0, 0, 0, 0], len: 9 })
# 🔍   index = SmallInt(12)
# ❌ No 'name' attribute found for node 20, available attrs: ["name", "index", "color", "size"]
# 🔍 Node 31: Found 2 attributes
# 🔍   index = SmallInt(33)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 51, 51, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 31, available attrs: ["color", "index", "size", "name"]
# 🔍 Node 12: Found 2 attributes
# 🔍   index = SmallInt(10)
# 🔍   name = CompactText(Inline { data: [77, 101, 109, 98, 101, 114, 95, 49, 48, 0, 0, 0, 0, 0, 0], len: 9 })
# ❌ No 'name' attribute found for node 12, available attrs: ["color", "index", "name", "size"]
# 🎯 GraphDataSource::interactive_embed called
# ✅ Bound and listening on 127.0.0.1:58897
# 📊 Serving 34 rows × 4 columns
# 🖼️  Graph visualization iframe generated for port 58897

# %% [markdown]
# ## Test 4: NodesTable and EdgesTable viz (fallback visualization)

# %%
# Test NodesTable viz (should show fallback)
print(f"NodesTable: {nt}")
print(f"Has viz accessor: {hasattr(nt, 'viz')}")

viz_html = nt.viz.show(backend='jupyter')
print(f"\nNodesTable viz HTML: {viz_html[:200]}...")

# Test EdgesTable viz (should show fallback)
print(f"\nEdgesTable: {et}")
print(f"Has viz accessor: {hasattr(et, 'viz')}")

viz_html = et.viz.show(backend='jupyter')
print(f"\nEdgesTable viz HTML: {viz_html[:200]}...")

# %% [markdown]
# ## Test 5: Server lifecycle utilities

# %%
# Test server listing functionality
print("Listing active Jupyter servers:")
from groggy import VizAccessor
VizAccessor.list_jupyter_servers()

print("\n" + "="*50 + "\n")

# Test server cleanup functionality
print("Cleaning up Jupyter servers:")
VizAccessor.cleanup_jupyter_servers()
# Out:
# Listing active Jupyter servers:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Test server listing functionality
#       2 print("Listing active Jupyter servers:")
# ----> 3 from groggy import VizAccessor
#       4 VizAccessor.list_jupyter_servers()
#       6 print("\n" + "="*50 + "\n")
#
# ImportError: cannot import name 'VizAccessor' from 'groggy' (/Users/michaelroth/Documents/Code/groggy/python-groggy/python/groggy/__init__.py)

# %% [markdown]
# ## Test 6: Error handling for invalid backend

# %%
# Test error handling for invalid backend
try:
    gt.viz.show(backend='invalid')
    print("ERROR: Should have raised an exception")
except ValueError as e:
    print(f"✅ Correctly caught error: {e}")
except Exception as e:
    print(f"⚠️ Unexpected error type: {type(e).__name__}: {e}")

# %% [markdown]
# ## Test 7: Default backend behavior

# %%
# Test default backend (should be 'jupyter')
print("Testing default backend:")
viz_html = gt.viz.show()  # No backend specified, should default to 'jupyter'
print(f"Default backend generated HTML: {len(viz_html)} characters")
print(f"Contains iframe: {'iframe' in viz_html.lower()}")

print("\n🎉 All tests completed! Integrated Jupyter backend is working.")
