# %%
import groggy as gr

# %%
g = gr.generators.meta_api_graph()
# Out:
# ✅ Loaded Meta API Graph: 12 nodes, 47 edges
#    This graph represents Groggy's complete API structure!

# %%
g.edges.table()
# Out:
# EdgesTable[47 x 6]

# %%
g.nodes.table()
# Out:
# NodesTable[12 x 5]

# %%
g.nodes.ids()
# Out:
# IntArray[12] [9, 6, 5]... (dtype: i64)
# 💡 Use .interactive() for rich table view or .astype('float64') for numerical operations

# %%
g.node_ids
# Out:
# IntArray[12] [9, 6, 5]... (dtype: i64)
# 💡 Use .interactive() for rich table view or .astype('float64') for numerical operations

# %%
g.
