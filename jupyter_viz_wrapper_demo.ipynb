# %% [markdown]
# # Groggy Jupyter Visualization Wrapper
#
# This notebook demonstrates the proper way to use Groggy's new viz accessor system in Jupyter environments with proper server lifecycle management.
#
# ## Overview
#
# The new `viz` accessor system provides clean access to interactive visualizations:
# - `gt.viz.show()` - GraphTable visualization
# - `nt.viz.show()` - NodesTable visualization
# - `et.viz.show()` - EdgesTable visualization
# - `sg.viz.show()` - Subgraph visualization
# - `sga.viz.show()` - ComponentsArray visualization
#
# This wrapper ensures that visualization servers stay alive during your Jupyter session and can be properly cleaned up when done.

# %%
# Import Required Libraries
import groggy as gr
from IPython.display import display, HTML
import weakref

print("📦 Imported groggy and IPython display modules")
print(f"🔧 Groggy version: {gr.__version__ if hasattr(gr, '__version__') else 'development'}")
# Out:
# 📦 Imported groggy and IPython display modules
# 🔧 Groggy version: 0.4.1

# %%
# Create Example Groggy Objects
# Create a sample graph to demonstrate the viz accessor functionality
print("🏗️  Creating example Groggy objects...")

# Generate the karate club graph as our demo data
g = gr.generators.karate_club()
print(f"📊 Created karate club graph with {len(g.nodes)} nodes and {len(g.edges)} edges")

# Get different view objects to demonstrate all viz accessors
gt = g.table()                    # GraphTable
nt = g.nodes.table()             # NodesTable  
et = g.edges.table()             # EdgesTable
sg = g.view()                    # Subgraph
sga = g.connected_components()   # ComponentsArray

print("✅ Created all object types:")
print(f"  📋 GraphTable (gt): {type(gt).__name__}")
print(f"  🔘 NodesTable (nt): {type(nt).__name__}")  
print(f"  🔗 EdgesTable (et): {type(et).__name__}")
print(f"  🎯 Subgraph (sg): {type(sg).__name__}")
print(f"  🧩 ComponentsArray (sga): {type(sga).__name__} with {len(sga)} components")
# Out:
# 🏗️  Creating example Groggy objects...
# 📊 Created karate club graph with 34 nodes and 78 edges
# ✅ Created all object types:
#   📋 GraphTable (gt): GraphTable
#   🔘 NodesTable (nt): NodesTable
#   🔗 EdgesTable (et): EdgesTable
#   🎯 Subgraph (sg): Subgraph
#   🧩 ComponentsArray (sga): ComponentsArray with 1 components

# %%
# Test the enhanced viz accessor after improved Jupyter detection
print("Testing enhanced viz accessor with improved detection:")

# Test auto-detect mode  
print("Auto-detect mode:")
result = g.nodes[g.degree() > 2].viz.show()
print(f"Result type: {type(result)}")

# Check if it's an IPython HTML object
if hasattr(result, '_repr_html_'):
    print("✅ SUCCESS: Returned IPython HTML object!")
    print("This should display automatically below:")
else:
    print("❌ Still returning string instead of HTML object")
    print(f"Result preview: {str(result)[:100]}...")

result
# Out:
# Testing enhanced viz accessor with improved detection:
# Auto-detect mode:
# ✅ Bound and listening on 127.0.0.1:8080
# 📊 Serving 22 rows × 4 columns
# /Users/michaelroth/Documents/Code/venv/lib/python3.9/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="http://127.0.0.1:8080" width="100%" height="420" style="border:0;border-radius:12px;"></iframe>
# Result type: <class 'NoneType'>
# ❌ Still returning string instead of HTML object
# Result preview: None...

# %%
# Fresh kernel test after clean rebuild
import sys
print("🔄 Fresh kernel test with clean groggy installation")

# Force fresh import after clean rebuild
import groggy as gr
print(f"✅ Groggy imported: {gr.__version__ if hasattr(gr, '__version__') else 'development'}")

# Create fresh graph
g = gr.generators.karate_club()
print(f"📊 Created graph: {len(g.nodes)} nodes, {len(g.edges)} edges")

# Test the viz accessor
print("\n🎯 Testing viz accessor:")
result = g.nodes[g.degree() > 2].viz.show()
print(f"Result type: {type(result)}")

# Check for IPython HTML object attributes
print(f"Has _repr_html_: {hasattr(result, '_repr_html_')}")
print(f"Has _repr_mimebundle_: {hasattr(result, '_repr_mimebundle_')}")

if hasattr(result, '_repr_html_'):
    print("✅ SUCCESS: This is an IPython HTML object!")
    print("The visualization should appear automatically below:")
else:
    print("❌ This is still a plain string")
    print(f"Content preview: {str(result)[:100]}...")

result
# Out:
# 🔄 Fresh kernel test with clean groggy installation
# ✅ Groggy imported: 0.4.1
# 📊 Created graph: 34 nodes, 78 edges
#
# 🎯 Testing viz accessor:
# 🌐 HTTP request from 127.0.0.1:56547
# ✅ Bound and listening on 127.0.0.1:8081
# 📊 Serving 22 rows × 4 columns
# <iframe src="http://127.0.0.1:8081" width="100%" height="420" style="border:0;border-radius:12px;"></iframe>
# Result type: <class 'NoneType'>
# Has _repr_html_: False
# Has _repr_mimebundle_: False
# ❌ This is still a plain string
# Content preview: None...

# %%
g.nodes[g.degree() > 2].viz.show(backend='jupyter')
# Out:
# 🌐 HTTP request from 127.0.0.1:56548
# 🌐 HTTP request from 127.0.0.1:56549
# 🌐 HTTP request from 127.0.0.1:56550
# 🌐 HTTP request from 127.0.0.1:56551
# 🌐 HTTP request from 127.0.0.1:56552
# 📱 WebSocket client connected: 127.0.0.1:56553
# 📱 WebSocket client connected: 127.0.0.1:56554
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 g.nodes[g.degree() > 2].viz.show(backend='jupyter')
#
# TypeError: VizAccessor.show() takes no keyword arguments

# %%
g.nodes.viz.show()
# Out:
# ✅ Bound and listening on 127.0.0.1:8082
# 📊 Serving 34 rows × 4 columns
# <iframe src="http://127.0.0.1:8082" width="100%" height="420" style="border:0;border-radius:12px;"></iframe>
# 🌐 HTTP request from 127.0.0.1:56605
# 🌐 HTTP request from 127.0.0.1:56606
# 🌐 HTTP request from 127.0.0.1:56607
# 📱 WebSocket client connected: 127.0.0.1:56608
# 📩 HANDLE CLIENT MESSAGE: 79 chars from 127.0.0.1:56608
# 📊 Client 127.0.0.1:56608 requested graph data
