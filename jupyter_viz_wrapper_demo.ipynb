# %% [markdown]
# # Groggy Jupyter Visualization Wrapper
#
# This notebook demonstrates the proper way to use Groggy's new viz accessor system in Jupyter environments with proper server lifecycle management.
#
# ## Overview
#
# The new `viz` accessor system provides clean access to interactive visualizations:
# - `gt.viz.show()` - GraphTable visualization
# - `nt.viz.show()` - NodesTable visualization
# - `et.viz.show()` - EdgesTable visualization
# - `sg.viz.show()` - Subgraph visualization
# - `sga.viz.show()` - ComponentsArray visualization
#
# This wrapper ensures that visualization servers stay alive during your Jupyter session and can be properly cleaned up when done.

# %%
# Import Required Libraries
import groggy as gr

# %%
g = gr.generators.meta_api_graph()
# Out:
# ✅ Loaded Meta API Graph: 12 nodes, 69 edges
#    This graph represents Groggy's complete API structure!

# %%
g.viz.show()
# Out:
# ✅ Bound and listening on 127.0.0.1:8080
# 📊 Serving 12 rows × 4 columns
# /Users/michaelroth/Documents/Code/venv/lib/python3.9/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="http://127.0.0.1:8080" width="100%" height="640" style="border:0;border-radius:12px;"></iframe>

# %%
g.viz.honeycomb()
# Out:
# 🔍 DEBUG: interactive_embed_with_layout called with WORKING STREAMING layout: Honeycomb { cell_size: 40.0, energy_optimization: true, iterations: 100 }
# 🔍 DEBUG: Created VizModule with 12 nodes and 69 edges
# 🔍 DEBUG: Creating streaming visualization with working server + advanced layout controls
# 🔍 DEBUG: ✨ STREAMING visualization created, starting server...
# ✅ Bound and listening on 127.0.0.1:8081
# 📊 Serving 12 rows × 4 columns
# 🚀 Interactive visualization server started at: http://127.0.0.1:8081
# 📊 Graph visualization: 12 nodes, 69 edges
# 🔍 DEBUG: ✨ STREAMING server started on port 8081 with WORKING CONTROLS
# 🔍 DEBUG: Generated STREAMING HTML with working server (length: 1150 chars)
# 🔍 Python FFI: honeycomb method called with cell_size=None, energy_opt=None, iterations=None
# 🔍 Python FFI: data_source found, calling interactive_embed_with_layout
# 🔍 Python FFI: About to call interactive_embed_with_layout with Honeycomb { cell_size: 40.0, energy_optimization: true, iterations: 100 }
# 🔍 Python FFI: interactive_embed_with_layout returned
# <div style="position: relative;">
#     <iframe src="http://127.0.0.1:8081" width="100%" height="640" frameborder="0" id="groggy-streaming-8081"></iframe>
#     <div style="font-size: 12px; color: #666; margin-top: 5px;">
#         ✨ <strong>Advanced Streaming Visualization</strong> on port 8081
#         <span style="margin-left: 10px;">🎛️ Includes working honeycomb layout & controls</span>
#     </div>
# </div>
# <script>
# // Enhanced keepalive for streaming server
# (function() {
#     const iframe = document.getElementById(\'groggy-streaming-8081\');
#     let pingInterval;
#
#     // Start pinging when iframe loads
#     iframe.onload = function() {
#         console.log(\'✨ Advanced Streaming visualization loaded on port 8081\');
#         pingInterval = setInterval(function() {
#             fetch(\'http://127.0.0.1:8081/api/health\')
#                 .catch(() => console.log(\'Streaming keepalive ping failed\'));
#         }, 30000);
#     };
#
#     // Clean up on page unload
#     window.addEventListener(\'beforeunload\', function() {
#         if (pingInterval) {
#             clearInterval(pingInterval);
#         }
#     });
# })();
# </script>
# 🍯 Honeycomb layout applied (cell_size: 40, optimization: true, iterations: 100)
# <div style="position: relative;">
#     <iframe src="http://127.0.0.1:8081" width="100%" height="640" frameborder="0" id="groggy-streaming-8081"></iframe>
#     <div style="font-size: 12px; color: #666; margin-top: 5px;">
#         ✨ <strong>Advanced Streaming Visualization</strong> on port 8081
#         <span style="margin-left: 10px;">🎛️ Includes working honeycomb layout & controls</span>
#     </div>
# </div>
# <script>
# // Enhanced keepalive for streaming server
# (function() {
#     const iframe = document.getElementById(\'groggy-streaming-8081\');
#     let pingInterval;
#
#     // Start pinging when iframe loads
#     iframe.onload = function() {
#         console.log(\'✨ Advanced Streaming visualization loaded on port 8081\');
#         pingInterval = setInterval(function() {
#             fetch(\'http://127.0.0.1:8081/api/health\')
#                 .catch(() => console.log(\'Streaming keepalive ping failed\'));
#         }, 30000);
#     };
#
#     // Clean up on page unload
#     window.addEventListener(\'beforeunload\', function() {
#         if (pingInterval) {
#             clearInterval(pingInterval);
#         }
#     });
# })();
# </script>
# 🌐 HTTP request from 127.0.0.1:60904
# 🌐 HTTP request from 127.0.0.1:60905
