# %% [markdown]
# # Groggy Jupyter Visualization Wrapper
#
# This notebook demonstrates the proper way to use Groggy's new viz accessor system in Jupyter environments with proper server lifecycle management.
#
# ## Overview
#
# The new `viz` accessor system provides clean access to interactive visualizations:
# - `gt.viz.show()` - GraphTable visualization
# - `nt.viz.show()` - NodesTable visualization
# - `et.viz.show()` - EdgesTable visualization
# - `sg.viz.show()` - Subgraph visualization
# - `sga.viz.show()` - ComponentsArray visualization
#
# This wrapper ensures that visualization servers stay alive during your Jupyter session and can be properly cleaned up when done.

# %%
# Import Required Libraries
import groggy as gr

# %%
g = gr.generators.karate_club()

# %%
g.viz.show(layout='circular')
# Out:
# 🚀 DEBUG: Starting RealtimeServer on port 8080 with cancellation
# 📊 DEBUG: Loaded initial snapshot with 34 nodes, 78 edges
# 📊 DEBUG: WsBridge storing snapshot with 34 nodes, 78 edges
# ✅ DEBUG: RealtimeServer listening on 8080
# 🌐 DEBUG: HTTP endpoint: http://127.0.0.1:8080/
# 🔌 DEBUG: WebSocket endpoint: ws://127.0.0.1:8080/ws
# 🔗 DEBUG: New connection from 127.0.0.1:49876
# 📋 DEBUG: Request: GET /ws HTTP/1.1
# 🔌 DEBUG: WebSocket upgrade request from 127.0.0.1:49876
# 🔗 DEBUG: New WebSocket stream from 127.0.0.1:49876
# 👤 DEBUG: Assigned client ID: 0
# 📊 DEBUG: Sending initial snapshot to client 0
# 📨 DEBUG: Received from client 0: {"payload":{"ChangeLayout":{"algorithm":"circular","params":{}}},"type":"control","version":1}
# 🔍 DEBUG: Attempting to parse control message: {"payload":{"ChangeLayout":{"algorithm":"circular","params":{}}},"type":"control","version":1}
# ✅ DEBUG: Parsed as WsMessage::Control format
# 🎮 DEBUG: Parsed control message: ChangeLayout { algorithm: "circular", params: {} }
# 🎮 DEBUG: Processing control message from client 0: ChangeLayout { algorithm: "circular", params: {} }
# 🎮 DEBUG: Processing control message from client 0: ChangeLayout { algorithm: "circular", params: {} }
# 📐 DEBUG: Processing layout change: circular
# ✅ DEBUG: Control message acknowledged by accessor (engine will emit updates)
# 📐 DEBUG: Forwarding ChangeLayout to engine: algorithm=circular
# 📐 DEBUG: Applying layout change to circular with params {}
# 📡 DEBUG: Forwarding engine update to WebSocket clients: UpdateEnvelope(UpdateEnvelope { timestamp_ms: 1759143064423, frame_id: 1, params_changed: None, graph_patch: None, positions: None, ui: None, view_changed: Some(Object {"view_2d": Object {"rotation": Number(0.0), "x": Number(0.0), "y": Number(0.0), "zoom": Number(1.0)}}) })
# 📡 DEBUG: Broadcasting update to 1 clients
# ⭕ DEBUG: Using circular layout
# 📡 DEBUG: Forwarding engine update to WebSocket clients: UpdateEnvelope(UpdateEnvelope { timestamp_ms: 1759143064424, frame_id: 2, params_changed: Some({"layout.algorithm": String("circular"), "layout": Object {"algorithm": String("circular"), "params": Object {}}}), graph_patch: None, positions: Some(PositionsPayload { positions: [NodePosition { node_id: 16, coords: [248.0158039070812, 0.0] }, NodePosition { node_id: 10, coords: [22.88
614, -130.563496078571] }, NodePosition { node_id: 26, coords: [110.55015664013871, 222.01464333353454] }, NodePosition { node_id: 0, coords: [-248.0158039070812, 3.037317603927646e-14] }, NodePosition { node_id: 5, coords: [-22.88401134747836, 246.9578122115683] }, NodePosition { node_id: 21, coords: [-210.8672864135562, -130.5634960785709] }, NodePosition { node_id: 15, coords: [-110.55015664013858, 222.01464333353456] }, NodePosition { node_id: 13, coords: [243.79286353713835, -45.572784378815165] }, NodePosition { node_id: 28, coords: [149.4629138038528, 197.9208841556085] }, NodePosition { node_id: 7, coords: [67.87274648234319, -238.5479601099521] }, NodePosition { node_id: 33, coords: [231.26784959674953, -89.59364224414021] }, NodePosition { node_id: 3, coords: [-231.26784959674956, -89.59364224414014] }, NodePosition { node_id: 6, coords: [110.55015664013855, -222.01464333353456] }, NodePosition { node_id: 12, coords: [210.8672864135562, 130.56349607857086] }, NodePosition { node_id: 4, coords: [-231.26784959674947, 89.59364224414028] }, NodePosition { node_id: 11, coords: [67.87274648234325, 238.5479601099521] }, NodePosition { node_id: 1, coords: [183.28589069898337, 167.08716664769935] }, NodePosition { node_id: 23, coords: [-149.462913803853, -197.92088415560838] }, NodePosition { node_id: 17, coords: [-110.55015664013885, -222.01464333353442] }, NodePosition { node_id: 22, coords: [-210.86728641355617, 130.56349607857095] }, NodePosition { node_id: 27, coords: [-183.28589069898345, 167.08716664769935] }, NodePosition { node_id: 19, coords: [183.28589069898322, -167.0871666476995] }, NodePosition { node_id: 2, coords: [22.884011347478495, -246.9578122115683] }, NodePosition { node_id: 31, coords: [-183.28589069898337, -167.08716664769935] }, NodePosition { node_id: 8, coords: [231.26784959674953, 89.5936422441402] }, NodePosition { node_id: 14, coords: [-243.79286353713835, 45.572784378815236] }, NodePosition { node_id: 32, coords: [-22.884011347478367, -246.9578122115683] }, NodePosition { node_id: 29, coords: [149.46291380385276, -197.92088415560858] }, NodePosition { node_id: 9, coords: [243.79286353713835, 45.572784378815236] }])
# 📡 DEBUG: Broadcasting update to 1 clients
# 📡 DEBUG: Forwarding engine update to WebSocket clients: LayoutChanged { algorithm: "circular", params: {} }
# 📡 DEBUG: Broadcasting update to 1 clients
# 📡 DEBUG: Forwarding engine update to WebSocket clients: LayoutChanged { algorithm: "circular", params: {} }
# 📡 DEBUG: Broadcasting update to 1 clients
# 🔌 DEBUG: Client 0 sent close
# 🔌 DEBUG: Client 0 disconnected
# <div style="position: relative;">
# <iframe src="http://127.0.0.1:8080/" width="100%" height="640" frameborder="0" style="border: 1px solid #ddd;"></iframe>
# </div>

# %%
g.nodes.table()
# Out:
# NodesTable[34 x 3]

# %%
g.nodes.table().filter('node_id > 10')
# Out:
# NodesTable[23 x 3]

# %%
table = g.nodes.table()

# %%
array = table['name']
# Out:
# 🔗 DEBUG: New connection from 127.0.0.1:49879
# 📋 DEBUG: Request: GET / HTTP/1.1
# 🌐 DEBUG: Serving static HTML page to 127.0.0.1:49879
# ✅ DEBUG: Static HTML page served to 127.0.0.1:49879
