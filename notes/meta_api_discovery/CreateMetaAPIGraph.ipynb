# %%
import groggy as gr
import json

# %%
# Streamlined API Meta-Graph Creation
# This replaces the complex 3-step process with a single focused extraction

import sys
sys.path.append('.')

# Import our streamlined extractor
from api_meta_graph_extractor import APIMetaGraphExtractor

# Create the extractor
extractor = APIMetaGraphExtractor()

# Extract the complete meta-graph
print("Starting API Meta-Graph extraction...")
meta_graph, summary = extractor.extract_complete_meta_graph()

print(f"\n🎉 Successfully created meta-graph!")
print(f"   Nodes (Types): {summary['meta_graph_stats']['nodes']}")
print(f"   Edges (Methods): {summary['meta_graph_stats']['edges']}")
print(f"   Types discovered: {summary['meta_graph_stats']['types_discovered']}")

# Show the graph structure
print(f"\nGraph object: {meta_graph}")
print(f"Node count: {meta_graph.node_count()}")
print(f"Edge count: {meta_graph.edge_count()}")
# Out:
# Starting API Meta-Graph extraction...
# API Meta-Graph Extraction
# ==================================================
# Discovering Groggy API structure...
#   Checking groggy module for available types...
#     Found AggregationFunction class (could not instantiate)
#     Found AggregationResult class (could not instantiate)
#     Created AttrName instance
#     Found AttrValue class (could not instantiate)
#     Found AttributeFilter class (could not instantiate)
#     Found BaseArray class (could not instantiate)
#     Created BaseTable instance
#     Found BranchInfo class (could not instantiate)
#     Created BranchName instance
#     Found Commit class (could not instantiate)
#     Found ComponentsArray class (could not instantiate)
#     Created DisplayConfig instance
#     Found EdgeFilter class (could not instantiate)
#     Created EdgeId instance
#     Found EdgeNotFoundError class (could not instantiate)
#     Found EdgesArray class (could not instantiate)
#     Found EdgesTable class (could not instantiate)
#     Found GraphMatrix class (could not instantiate)
#     Found GraphTable class (could not instantiate)
#     Created GroggyError instance
#     Found GroupedAggregationResult class (could not instantiate)
#     Found HistoricalView class (could not instantiate)
#     Found HistoryStatistics class (could not instantiate)
#     Created InvalidInputError instance
#     Found MetaNode class (could not instantiate)
#     Found MetaNodeArray class (could not instantiate)
#     Found NodeFilter class (could not instantiate)
#     Created NodeId instance
#     Found NodeNotFoundError class (could not instantiate)
#     Found NodesArray class (could not instantiate)
#     Found NodesTable class (could not instantiate)
#     Found NotImplementedError class (could not instantiate)
#     Found NumArray class (could not instantiate)
#     Found PyAttributeCollection class (could not instantiate)
#     Found PyResultHandle class (could not instantiate)
#     Created StateId instance
#     Found StatsArray class (could not instantiate)
#     Found Subgraph class (could not instantiate)
#     Found SubgraphArray class (could not instantiate)
#     Found TableFormatter class (could not instantiate)
#   Creating objects through Graph API usage...
#     Found NodesAccessor: <class 'builtins.NodesAccessor'>
#     Found EdgesAccessor: <class 'builtins.EdgesAccessor'>
#     Found GraphTable: <class 'groggy.GraphTable'>
#     Found NodesTable: <class 'groggy.NodesTable'>
#     Found EdgesTable: <class 'groggy.EdgesTable'>
#     Found NodesArray: <class 'builtins.NodesArray'>
#     Found NumArray: <class 'builtins.NumArray'>
#     Found SubgraphArray: <class 'builtins.SubgraphArray'>
#     Found TableArray: <class 'builtins.TableArray'>
#     Found Subgraph: <class 'builtins.Subgraph'>
#     Found GraphMatrix: <class 'builtins.GraphMatrix'>
#     Found ComponentsArray: <class 'builtins.ComponentsArray'>
#   Total objects discovered: 22
#   Object types: Graph, AttrName, BaseTable, BranchName, DisplayConfig, EdgeId, GroggyError, InvalidInputError, NodeId, StateId, NodesAccessor, EdgesAccessor, GraphTable, NodesTable, EdgesTable, NodesArray, NumArray, SubgraphArray, TableArray, Subgraph, GraphMatrix, ComponentsArray
#   Analyzing Graph...
#   Analyzing AttrName...
#     Warning: Could not analyze AttrName.count: no signature found for builtin <built-in method count of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.endswith: no signature found for builtin <built-in method endswith of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.find: no signature found for builtin <built-in method find of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.format: no signature found for builtin <built-in method format of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.format_map: no signature found for builtin <built-in method format_map of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.index: no signature found for builtin <built-in method index of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.maketrans: <built-in method maketrans of type object at 0x1014b9110> builtin has invalid signature
#     Warning: Could not analyze AttrName.rfind: no signature found for builtin <built-in method rfind of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.rindex: no signature found for builtin <built-in method rindex of str object at 0x100a70670>
#     Warning: Could not analyze AttrName.startswith: no signature found for builtin <built-in method startswith of str object at 0x100a70670>
#   Analyzing BaseTable...
#   Analyzing BranchName...
#     Warning: Could not analyze BranchName.count: no signature found for builtin <built-in method count of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.endswith: no signature found for builtin <built-in method endswith of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.find: no signature found for builtin <built-in method find of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.format: no signature found for builtin <built-in method format of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.format_map: no signature found for builtin <built-in method format_map of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.index: no signature found for builtin <built-in method index of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.maketrans: <built-in method maketrans of type object at 0x1014b9110> builtin has invalid signature
#     Warning: Could not analyze BranchName.rfind: no signature found for builtin <built-in method rfind of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.rindex: no signature found for builtin <built-in method rindex of str object at 0x100a70670>
#     Warning: Could not analyze BranchName.startswith: no signature found for builtin <built-in method startswith of str object at 0x100a70670>
#   Analyzing DisplayConfig...
#   Analyzing EdgeId...
#     Warning: Could not analyze EdgeId.conjugate: no signature found for builtin <built-in method conjugate of int object at 0x100a42910>
#   Analyzing GroggyError...
#     Warning: Could not analyze GroggyError.with_traceback: no signature found for builtin <built-in method with_traceback of GroggyError object at 0x1037d5be0>
#   Analyzing InvalidInputError...
#     Warning: Could not analyze InvalidInputError.with_traceback: no signature found for builtin <built-in method with_traceback of InvalidInputError object at 0x1037d5ca0>
#   Analyzing NodeId...
#     Warning: Could not analyze NodeId.conjugate: no signature found for builtin <built-in method conjugate of int object at 0x100a42910>
#   Analyzing StateId...
#     Warning: Could not analyze StateId.conjugate: no signature found for builtin <built-in method conjugate of int object at 0x100a42910>
#   Analyzing NodesAccessor...
#   Analyzing EdgesAccessor...
#   Analyzing GraphTable...
#   Analyzing NodesTable...
#   Analyzing EdgesTable...
#   Analyzing NodesArray...
#   Analyzing NumArray...
#   Analyzing SubgraphArray...
#   Analyzing TableArray...
#   Analyzing Subgraph...
#   Analyzing GraphMatrix...
#   Analyzing ComponentsArray...
# Discovered 525 methods across 22 object types
# Found 41 unique types
#
# Building meta-graph...
#   Adding 41 type nodes...
#   Adding 525 method edges...
# Meta-graph created: 41 nodes, 525 edges
#
# 🎉 Successfully created meta-graph!
#    Nodes (Types): 41
#    Edges (Methods): 525
#    Types discovered: 41
#
# Graph object: Graph(nodes=41, edges=525)
# Node count: 41
# Edge count: 525

# %%
meta_graph.nodes.table()
# Out:
# NodesTable[41 x 8]

# %%
meta_graph.edges.table().column_names
# Out:
# ['doc',
#  'edge_id',
#  'enhanced_signature',
#  'is_property',
#  'method_full_name',
#  'name',
#  'object_type',
#  'parameter_types',
#  'parameters_count',
#  'relationship',
#  'requires_parameters',
#  'return_type',
#  'signature',
#  'source',
#  'source_object',
#  'source_type',
#  'target']

# %%
meta_graph.edges.table()
# Out:
# EdgesTable[525 x 17]

# %%
meta_graph.edges.table()[['name', 'source_type', 'return_type']]
# Out:
# EdgesTable[525 x 6]

# %%
meta_graph.edges[meta_graph.edges['source_type'] == 'GraphMatrix'].edges.table()[['name', 'source_type', 'return_type']]
# Out:
# EdgesTable[82 x 6]

# %%
# Access nodes table properly
try:
    nodes_table = meta_graph.nodes()
    print(f"Nodes table shape: {nodes_table.shape()}")
    print("\nFirst 5 type nodes:")
    nodes_table.head(5)
except Exception as e:
    print(f"Error accessing nodes: {e}")
    print("Showing discovered types from summary instead:")
    for i, type_name in enumerate(sorted(summary['discovery_data']['types'])[:5]):
        status = "Core" if type_name in summary['type_info'] else "Inferred"
        print(f"  {i+1}. {type_name} ({status})")
# Out:
# Error accessing nodes: 'builtins.NodesAccessor' object is not callable
# Showing discovered types from summary instead:
#   1. AttrName (Core)
#   2. BaseArray (Inferred)
#   3. BaseTable (Core)
#   4. BranchName (Core)
#   5. Commit (Inferred)

# %%
meta_graph.edges.group_by('source_object')[7].edges.table()
# Out:
# EdgesTable[36 x 17]

# %%
import matplotlib.pyplot as plt

plt.imshow(meta_graph.adj().data)

# %%
meta_graph.table().save_bundle('./meta_graph_bundle/')
